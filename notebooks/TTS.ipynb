# %% [markdown]
# # Prototyping for the Text to Speech Module

# %%
import torch
from TTS.api import TTS

# Get device
device = "cuda" if torch.cuda.is_available() else "cpu"

# List available 🐸TTS models
print(TTS().list_models())
# Out:
# <TTS.utils.manage.ModelManager object at 0x317558fa0>

# %%
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)
# Out:
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: xtts

# %%
tts.tts_to_file(text="My name is David, hello EESTEC challenge", speaker_wav="file.mp3", language="en", file_path="output.wav")
# Out:
#  > Text splitted to sentences.
# ['My name is David, hello EESTEC challenge']
#  > Processing time: 11.20193600654602
#  > Real-time factor: 3.269999588862791
# 'output.wav'

# %%
from IPython.display import Audio

# %%
Audio("output.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
